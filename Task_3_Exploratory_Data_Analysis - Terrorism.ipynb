# %% [markdown]
# ## The Spark Foundation

# %% [markdown]
# ## Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’

# %% [markdown]
# ## Task 3

# %% [markdown]
# ## Author- Mona Kumari

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing Data

# %%
file = r'C:\Users\PC\Downloads\The Sparks Projects\Data\globalterrorismdb_0718dist.csv'

data  = pd.read_csv(file)

# %% [markdown]
# ## Read Dataset

# %%
data.head(7)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
#
# [7 rows x 135 columns]

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %% [markdown]
# ## Renaming Columns

# %%
data.rename(columns = {  'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'city':'City', 'region_txt':'Region', 'gname':'Group', 'motive':'Motive', 'nkill':'Kill', 'nwound':'Wound',
                       'summary':'Summary', 'target1':'Target1',  'attacktype1_txt':'attacktype1', 'weaptype1_txt':'weaptype1', 'targsubtype1_txt':'Targsubtype'}, inplace= True)

# %%
data.head(7)
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  1.970000e+11  1970      7    2        NaN         0        NaN       58
# 1  1.970000e+11  1970      0    0        NaN         0        NaN      130
# 2  1.970010e+11  1970      1    0        NaN         0        NaN      160
# 3  1.970010e+11  1970      1    0        NaN         0        NaN       78
# 4  1.970010e+11  1970      1    0        NaN         0        NaN      101
# 5  1.970010e+11  1970      1    1        NaN         0        NaN      217
# 6  1.970010e+11  1970      1    2        NaN         0        NaN      218
#
#               Country  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
#
# [7 rows x 135 columns]

# %%
data.columns.values
# Out:
# array(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region', 'Region',
#        'provstate', 'City', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'Summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1', 'attacktype2',
#        'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1',
#        'targtype1_txt', 'targsubtype1', 'Targsubtype', 'corp1', 'Target1',
#        'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt',
#        'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2',
#        'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3',
#        'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt',
#        'Group', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3',
#        'Motive', 'guncertain1', 'guncertain2', 'guncertain3',
#        'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode',
#        'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
#        'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weaptype1',
#        'weaptype1', 'weapsubtype1', 'weapsubtype1_txt', 'weaptype2',
#        'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3',
#        'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4',
#        'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail',
#        'Kill', 'nkillus', 'nkillter', 'Wound', 'nwoundus', 'nwoundte',
#        'property', 'propextent', 'propextent_txt', 'propvalue',
#        'propcomment', 'ishostkid', 'nhostkid', 'nhostkidus', 'nhours',
#        'ndays', 'divert', 'kidhijcountry', 'ransom', 'ransomamt',
#        'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote',
#        'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
#        'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY', 'related'], dtype=object)

# %%
data.shape
# Out:
# (181691, 135)

# %%
data_new= data[['Year','Month','Day','Country','City','Region','Group','Motive','Kill','Wound','Summary','Target1', 'attacktype1','weaptype1', 'Targsubtype']]
data_new.head(6)
# Out:
#    Year  Month  Day             Country           City  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
# 5  1970      1    1       United States          Cairo
#
#                         Region                               Group  \
# 0  Central America & Caribbean                              MANO-D
# 1                North America  23rd of September Communist League
# 2               Southeast Asia                             Unknown
# 3               Western Europe                             Unknown
# 4                    East Asia                             Unknown
# 5                North America                  Black Nationalists
#
#                                            Motive  Kill  Wound  \
# 0                                             NaN   1.0    0.0
# 1                                             NaN   0.0    0.0
# 2                                             NaN   1.0    0.0
# 3                                             NaN   NaN    NaN
# 4                                             NaN   NaN    NaN
# 5  To protest the Cairo Illinois Police Deparment   0.0    0.0
#
#                                              Summary  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  1/1/1970: Unknown African American assailants ...
#
#                      Target1 attacktype1                     attacktype1  \
# 0               Julio Guzman           1                   Assassination
# 1    Nadine Chaval, daughter           6     Hostage Taking (Kidnapping)
# 2                   Employee           1                   Assassination
# 3               U.S. Embassy           3               Bombing/Explosion
# 4             U.S. Consulate           7  Facility/Infrastructure Attack
# 5  Cairo Police Headquarters           2                   Armed Assault
#
#   weaptype1   weaptype1                                        Targsubtype
# 0        13     Unknown                                     Named Civilian
# 1        13     Unknown  Diplomatic Personnel (outside of embassy, cons...
# 2        13     Unknown                    Radio Journalist/Staff/Facility
# 3         6  Explosives                                  Embassy/Consulate
# 4         8  Incendiary                                  Embassy/Consulate
# 5         5    Firearms    Police Building (headquarters, station, school)

# %%
data_new.shape
# Out:
# (181691, 17)

# %%
data_new.dtypes
# Out:
# Year             int64
# Month            int64
# Day              int64
# Country         object
# City            object
# Region          object
# Group           object
# Motive          object
# Kill           float64
# Wound          float64
# Summary         object
# Target1         object
# attacktype1      int64
# attacktype1     object
# weaptype1        int64
# weaptype1       object
# Targsubtype     object
# dtype: object

# %%
data_new.isnull().sum()/len(data_new)*100
# Out:
# Year            0.000000
# Month           0.000000
# Day             0.000000
# Country         0.000000
# City            0.238867
# Region          0.000000
# Group           0.000000
# Motive         72.171984
# Kill            5.676120
# Wound           8.977330
# Summary        36.396409
# Target1         0.350045
# attacktype1     0.000000
# attacktype1     0.000000
# weaptype1       0.000000
# weaptype1       0.000000
# Targsubtype     5.709144
# dtype: float64

# %%
data_new.drop(['Summary', 'Motive'], axis=1,inplace=True)

# %%
data_new
# Out:
#         Year  Month  Day             Country           City  \
# 0       1970      7    2  Dominican Republic  Santo Domingo
# 1       1970      0    0              Mexico    Mexico city
# 2       1970      1    0         Philippines        Unknown
# 3       1970      1    0              Greece         Athens
# 4       1970      1    0               Japan        Fukouka
# ...      ...    ...  ...                 ...            ...
# 181686  2017     12   31             Somalia  Ceelka Geelow
# 181687  2017     12   31               Syria         Jableh
# 181688  2017     12   31         Philippines       Kubentog
# 181689  2017     12   31               India         Imphal
# 181690  2017     12   31         Philippines  Cotabato City
#
#                              Region  \
# 0       Central America & Caribbean
# 1                     North America
# 2                    Southeast Asia
# 3                    Western Europe
# 4                         East Asia
# ...                             ...
# 181686           Sub-Saharan Africa
# 181687   Middle East & North Africa
# 181688               Southeast Asia
# 181689                   South Asia
# 181690               Southeast Asia
#
#                                              Group  Kill  Wound  \
# 0                                           MANO-D   1.0    0.0
# 1               23rd of September Communist League   0.0    0.0
# 2                                          Unknown   1.0    0.0
# 3                                          Unknown   NaN    NaN
# 4                                          Unknown   NaN    NaN
# ...                                            ...   ...    ...
# 181686                                  Al-Shabaab   1.0    2.0
# 181687                           Muslim extremists   2.0    7.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)   0.0    0.0
# 181689                                     Unknown   0.0    0.0
# 181690                                     Unknown   0.0    0.0
#
#                         Target1 attacktype1                     attacktype1  \
# 0                  Julio Guzman           1                   Assassination
# 1       Nadine Chaval, daughter           6     Hostage Taking (Kidnapping)
# 2                      Employee           1                   Assassination
# 3                  U.S. Embassy           3               Bombing/Explosion
# 4                U.S. Consulate           7  Facility/Infrastructure Attack
# ...                         ...         ...                             ...
# 181686               Checkpoint           2                   Armed Assault
# 181687         Hmeymim Air Base           3               Bombing/Explosion
# 181688                   Houses           7  Facility/Infrastructure Attack
# 181689                   Office           3               Bombing/Explosion
# 181690                  Unknown           3               Bombing/Explosion
#
#        weaptype1   weaptype1  \
# 0             13     Unknown
# 1             13     Unknown
# 2             13     Unknown
# 3              6  Explosives
# 4              8  Incendiary
# ...          ...         ...
# 181686         5    Firearms
# 181687         6  Explosives
# 181688         8  Incendiary
# 181689         6  Explosives
# 181690         6  Explosives
#
#                                               Targsubtype
# 0                                          Named Civilian
# 1       Diplomatic Personnel (outside of embassy, cons...
# 2                         Radio Journalist/Staff/Facility
# 3                                       Embassy/Consulate
# 4                                       Embassy/Consulate
# ...                                                   ...
# 181686                                Military Checkpoint
# 181687      Military Barracks/Base/Headquarters/Checkpost
# 181688                          House/Apartment/Residence
# 181689                Government Building/Facility/Office
# 181690                                                NaN
#
# [181691 rows x 15 columns]

# %%
data_new.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# City             434
# Region             0
# Group              0
# Kill           10313
# Wound          16311
# Target1          636
# attacktype1        0
# attacktype1        0
# weaptype1          0
# weaptype1          0
# Targsubtype    10373
# dtype: int64

# %%
data_new['City'].fillna(value='Not specified', inplace=True)
data_new['Target1'].fillna(value='Unknown', inplace=True)
data_new['Targsubtype'].fillna(value='Not specified', inplace=True)

# %%
print(data_new['Kill'].mode())
print(data_new['Wound'].mode())
# Out:
# 0    0.0
# dtype: float64
# 0    0.0
# dtype: float64

# %%
data_new['Kill']= data_new['Kill'].fillna(0)
data_new['Wound'] = data_new['Wound'].fillna(0)

# %%
data_new.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# City             434
# Region             0
# Group              0
# Kill               0
# Wound              0
# Target1          636
# attacktype1        0
# attacktype1        0
# weaptype1          0
# weaptype1          0
# Targsubtype    10373
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(11,8))
sns.heatmap(data_new.corr(), annot=True)

# %%
data_new['Year'].value_counts().sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %% [markdown]
# ## Number of Terrorist Activities each Year

# %%
Year = data_new['Year'].unique()
count_of_years = data_new['Year'].value_counts().sort_index()
plt.figure(figsize=(15,8))
sns.barplot(x= Year, y= count_of_years, palette= 'gist_earth_r')
plt.xticks(rotation = 55)
plt.xlabel('Year of attack')
plt.ylabel('Number of attack each year')
plt.show()

# %%
data_new.groupby(['Region']).count()['Kill']
# Out:
# Region
# Australasia & Oceania            282
# Central America & Caribbean    10344
# Central Asia                     563
# East Asia                        802
# Eastern Europe                  5144
# Middle East & North Africa     50474
# North America                   3456
# South America                  18978
# South Asia                     44974
# Southeast Asia                 12485
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Name: Kill, dtype: int64

# %%
plt.subplots(figsize=(12,7))
data_new.groupby(['Region']).count()['Kill'].plot()
plt.xticks(rotation=20)
plt.ylabel('casualities')
# Out:
# Text(0, 0.5, 'casualities')

# %%
data_new.groupby(['Region']).count()['Wound']
# Out:
# Region
# Australasia & Oceania            282
# Central America & Caribbean    10344
# Central Asia                     563
# East Asia                        802
# Eastern Europe                  5144
# Middle East & North Africa     50474
# North America                   3456
# South America                  18978
# South Asia                     44974
# Southeast Asia                 12485
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Name: Wound, dtype: int64

# %%
plt.subplots(figsize=(12,8))
data_new.groupby(['Region']).count()['Wound'].plot()
plt.xticks(rotation=30)
plt.ylabel('casualities')
# Out:
# Text(0, 0.5, 'casualities')

# %% [markdown]
# ## Top Countries affected by Terror Attacks

# %%
plt.subplots(figsize=(14,5))
sns.countplot('Country', data=data_new, palette='PiYG', order=data_new['Country'].value_counts()[:35].index)
plt.xticks(rotation=98)
plt.xlabel('Country', fontsize=15)
plt.ylabel('Number of attacks', fontsize=15)
plt.title('Number of attack by country')
plt.show()
print("we can conclude that the country which was mostly attacks is 'Iraq' . ")
# Out:
# we can conclude that the country which was mostly attacks is 'Iraq' .
